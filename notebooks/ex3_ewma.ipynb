# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

rolling_period = 20

#write a function to open a json file and return a dataframe
def read_json(path, env, algo, seed):
    with open(path + "metrics.json", "r") as f:
        data = json.load(f)

    data = data[env][algo][seed]
    records = {}
    for key in data.keys():
        n = key.split("_")[1]
        if len(n) > 3: continue # skip abs metric
        entry = {"mean_episode_returns": data[key]["mean_episode_returns"][0]}
        records[int(n)] = entry
    df = pd.DataFrame.from_dict(records, orient="index")
    df[f"rolling_{rolling_period}"] = df["mean_episode_returns"].rolling(rolling_period).mean()
    
    return df

# %%
root = "../results/ppo/"
env = "CartPole-v1"
# env = "SpaceInvaders-MinAtar"
# data_1 = read_json(root + "env1/", env, "PPO", "seed_42")
d_4 = read_json(root + "env4/", env, "PPO", "seed_42")

eroot = "../results/ppoe/"
ed_4 = read_json(eroot + "env4/", env, "ppoe", "seed_42")

# %%
# ax = ed_4.plot(y="rolling_20", label="ppoe")
# d_4.plot(y="rolling_20", label="ppo", ax=ax)


ax = ed_4.plot(y="mean_episode_returns", label="ppoe")
d_4.plot(y="mean_episode_returns", label="ppo", ax=ax)
# Out:
# <Axes: >

# %%
def read_system_json(algo, env, env_n, seed):
    seed = f"seed_{seed}"
    path = f"../results/{algo}/{env}/envs_{env_n}/{seed}/"
    with open(path + "metrics.json", "r") as f:
        data = json.load(f)

    data = data[env][algo][seed]
    records = {}
    for key in data.keys():
        n = key.split("_")[1]
        if len(n) > 3: continue # skip abs metric
        entry = {"mean_episode_returns": data[key]["mean_episode_returns"][0]}
        records[int(n)] = entry
    df = pd.DataFrame.from_dict(records, orient="index")
    df[f"rolling_{rolling_period}"] = df["mean_episode_returns"].rolling(rolling_period).mean()
    
    return df

# %%
env = "SpaceInvaders-MinAtar"

env_ns = [1, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

ax = plt.gca()

i = 0
for env_n in env_ns:
    for seed in seeds:
        df = read_system_json("ppo", env, env_n, seed)
        df.plot(y="mean_episode_returns", alpha=0.2, ax=ax, color=colors[i])
        df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax, color=colors[i])

        i += 1

# %%
env = "SpaceInvaders-MinAtar"

env_ns = [1, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'yellow', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

ax = plt.gca()

i = 0
for env_n in env_ns:
    for seed in seeds:
        df = read_system_json("ppo_ewma", env, env_n, seed)
        df.plot(y="mean_episode_returns", alpha=0.4, ax=ax, color=colors[i])
        df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax, color=colors[i])

        i += 1

# %%
env = "SpaceInvaders-MinAtar"

env_ns = [1, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'yellow', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

ax = plt.gca()

i = 0
for env_n in env_ns:
    for seed in seeds:
        df = read_system_json("ppo_ewma", env, env_n, seed)
        df.plot(y="rolling_20", label=f"ppo_ewma_{env_n}_{seed}", ax=ax)

        df = read_system_json("ppo", env, env_n, seed)
        df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax)

        i += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[47], line 15
#      12 df = read_system_json("ppo_ewma", env, env_n, seed)
#      13 df.plot(y="rolling_20", label=f"ppo_ewma_{env_n}_{seed}", ax=ax)
# ---> 15 df = read_system_json("ppo", env, env_n, seed)
#      16 df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax)
#      18 i += 1
#
# Cell In[26], line 4, in read_system_json(algo, env, env_n, seed)
#       2 seed = f"seed_{seed}"
#       3 path = f"../results/{algo}/{env}/envs_{env_n}/{seed}/"
# ----> 4 with open(path + "metrics.json", "r") as f:
#       5     data = json.load(f)
#       7 data = data[env][algo][seed]
#
# File ~/Documents/RacingRepos/ppo/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/ppo/SpaceInvaders-MinAtar/envs_8/seed_42/metrics.json'

# %%
env = "SpaceInvaders-MinAtar"

env_ns = [1, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'yellow', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

# ax = plt.gca()
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize=(12, 10))

i = 0
for env_n in env_ns:
    for seed in seeds:
        ax = axs[i//3][i%3]
        df = read_system_json("ppo_ewma", env, env_n, seed)
        df.plot(y="rolling_20", label=f"ppo_ewma_{env_n}_{seed}", ax=ax)

        df = read_system_json("ppo", env, env_n, seed)
        df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax)

        ax.grid(True)
        ax.set_title(f"env_{env_n}_{seed}")
        ax.set_ylim(30, 135)


        i += 1
